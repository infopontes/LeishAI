# %%
import pandas as pd

# ==============================================================================
# --- 1. Carregando e Pré-processando os Dados ---
# ==============================================================================
print("--- 1. Carregando e Pré-processando os Dados ---")

# Carregar o dataset
file_path = '../../data/raw/leish_dataset.csv'
df = pd.read_csv(file_path)
# Out:
# --- 1. Carregando e Pré-processando os Dados ---

# %%
df
# Out:
#     diagnosis general_state ectoparasites nutritional_state             coat  \
# 0    negativo           bom       ausente          adequado           normal
# 1    negativo           bom       ausente          adequado           normal
# 2    negativo           bom          leve          adequado           normal
# 3    negativo           bom       ausente          adequado           normal
# 4    negativo           bom          leve     leve_moderado           normal
# ..        ...           ...           ...               ...              ...
# 451  positivo           bom          leve          adequado  leves_moderadas
# 452  positivo           bom       ausente          adequado  leves_moderadas
# 453  positivo           bom       ausente          adequado           normal
# 454  positivo           bom       ausente          adequado           normal
# 455  negativo           bom          leve     leve_moderado  leves_moderadas
#
#                nails           mucosa_color muzzle_ear_lesion  \
# 0             normal                 normal          presente
# 1             normal                 normal           ausente
# 2             normal                 normal           ausente
# 3    leves_moderadas                 normal           ausente
# 4    leves_moderadas                 normal           ausente
# ..               ...                    ...               ...
# 451  leves_moderadas                 normal          presente
# 452  leves_moderadas  levemente_hipercorada          presente
# 453           normal                 normal           ausente
# 454           normal                 normal           ausente
# 455  leves_moderadas  levemente_hipercorada          presente
#
#          lymph_nodes blepharitis     conjunctivitis  alopecia  bleeding  \
# 0             normal     ausente            Ausente   ausente  presente
# 1             normal     ausente            Ausente   ausente   ausente
# 2             normal     ausente            Ausente   ausente  presente
# 3             normal     ausente            Ausente   ausente   ausente
# 4    leves_moderadas     ausente            Ausente   ausente   ausente
# ..               ...         ...                ...       ...       ...
# 451           normal     ausente            Ausente   ausente   ausente
# 452  leves_moderadas    presente  Conjuntivite Leve  presente  presente
# 453  leves_moderadas     ausente            Ausente  presente   ausente
# 454  leves_moderadas     ausente            Ausente   ausente   ausente
# 455  leves_moderadas     ausente            Ausente   ausente   ausente
#
#        skin_lesion muzzle_lip_depigmentation animal_sex  breed_name
# 0          Ausente                   ausente          M         SRD
# 1          Ausente                   ausente          M         SRD
# 2          Ausente                   ausente          M      Poodle
# 3          Ausente                   ausente          F      PASTOR
# 4          Ausente                   ausente          F         SRD
# ..             ...                       ...        ...         ...
# 451        Ausente                   ausente          F         SRD
# 452  Leve/Moderada                  presente          M  Rottweiler
# 453        Ausente                   ausente          M    American
# 454        Ausente                   ausente          M     Mestiço
# 455        Ausente                   ausente          M         SRD
#
# [456 rows x 17 columns]
